# %%
from agents.DQN_Agent import DQN_Agent
from helpers.plot_util import *
from helpers.render_model import test_instances_of_env

# %%
agent= DQN_Agent(
                 env_name='LunarLander-v2',
                 gamma=0.99,
                 epsilon=1.0,
                 layer1_size=128, 
                 layer2_size=64,    
                 lr=0.001, 
                 mem_size=1000000, 
                 batch_size=64,
                 epsilon_dec=0.0001,
                 epsilon_end=0.01,
                 reproduce_seed=None#42
                 )

# %% [markdown]
# # Train DQN_agent

# %%
agent.train_multiple_episodes(num_episodes=500)      ## 500 was good
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Eps: 388 ,  Eps steps: 581 ,Epsilon: 0.01, Ep_Reward : 213.80 , Average_Reward : 213.37
# Mean Reward over last 100 ep more than 300
# Saving Model info.....
#
#  LunarLander-v2 Problem took 388 episodes

# %% [markdown]
# ### Get recently trained model information

# %%
model,book_keeping=agent.get_trained_model_info()

# %% [markdown]
# ### Learning Plots

# %%
learning_plot(book_keeping)

# %% [markdown]
# ### Save the trained model manually

# %%
agent.save_model()
# Out:
# DQN_trained_models/LunarLander-v2/dqn_model_20211107-181429.h5

# %% [markdown]
# ### If you want to use a pretrained model use this cell

# %%
model,book_keeping = agent.load_pre_trained_model_info(timestr="20211108-080323")
learning_plot(book_keeping)

# %% [markdown]
# ### Test Cases for the LunarLander-v2

# %%
test_cases_data , image_paths  = test_instances_of_env(
                                        model=model,
                                        test_cases=[42,900,930,180,660,240,960,450,30,90,150,210,330,420,510,75],
                                        env_name=agent.env_name
                                       )
# Out:
# Tests # 42 , Rewards 240.29430339046863 , Steps 442
# Tests # 900 , Rewards 218.85389462580065 , Steps 492
# Tests # 930 , Rewards 191.07481878757454 , Steps 701
# Tests # 180 , Rewards 231.8394613487899 , Steps 330
# Tests # 660 , Rewards 189.6356412674745 , Steps 661
# Tests # 240 , Rewards 208.90583816207243 , Steps 447
# Tests # 960 , Rewards 252.7770355744805 , Steps 525
# Tests # 450 , Rewards 262.1296941251925 , Steps 417
# Tests # 30 , Rewards 207.69439782809602 , Steps 519
# Tests # 90 , Rewards 220.66035025983672 , Steps 384
# Tests # 150 , Rewards 271.5465008372392 , Steps 398
# Tests # 210 , Rewards 199.73540586789926 , Steps 511
# Tests # 330 , Rewards 263.2953649873351 , Steps 350
# Tests # 420 , Rewards 187.32632839768712 , Steps 444
# Tests # 510 , Rewards 234.6379655302235 , Steps 550
# Tests # 75 , Rewards 230.77711936527245 , Steps 606

# %% [markdown]
# ### Plot Test cases data

# %%
plot_test_cases(test_cases_data)

# %% [markdown]
# ### Render Test Case images for the LunarLander-v2

# %%
import IPython.display as display
import ipywidgets as widgets
from ipywidgets import GridspecLayout

x=len(test_cases_data)//4
y=len(test_cases_data)//4
grid = GridspecLayout(x, y)

for i in range(x):
    for j in range(y):
        img=open(image_paths[4*i+j],'rb').read()
        grid[i, j] = widgets.Image(value=img, format='gif', width=220, height=510)

grid
# Out:
# GridspecLayout(children=(Image(value=b'GIF89aX\x02\x90\x01\x83\x00\x00\x00\x00\x00\xcc\xcc\x0033ff3f3fffff33\x…

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cbe52eb0-6905-4004-8022-6248894772ce' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
