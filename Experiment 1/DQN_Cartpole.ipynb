# %%
import sys
sys.path.append('..')
  
# importing
from agents.DQN_Agent import DQN_Agent
from helpers.plot_util import *

# %%
agent= DQN_Agent(
                 env_name="CartPole-v1",
                 gamma=0.98,
                 epsilon=1.0,
                 layer1_size=16, 
                 layer2_size=16,    
                 alpha=0.001, 
                 C=1000000, 
                 B=64,
                 epsilon_dec=0.0001,
                 epsilon_end=0.01,
                 reproduce_seed=None#42
                 )

# %%
agent.train_multiple_episodes(num_episodes=500)    ## 500 was good hann tha toh acha kya kahte ho aap
model,book_keeping=agent.get_trained_model_info()
# plot Learning curve
DQN_learning_plot(book_keeping)
# Out:
# Ep: 500 ,  Ep_Steps: 97 ,Epsilon: 0.01, Ep_Reward : 97.00 , Average_Reward : 298.8689
#  Agent trained.....
#
#  Saving Model info.....
#
#  CartPole-v1 Problem took 500 episodes

# %%
if agent.trained:
    test_cases_data,image_paths =agent.run_test_instances(case_list=[42,900,930,180,660,240,960,450,30,90,150,210,330,420,510,75], model_=model)
    # Plot Test cases data
    plot_test_cases(test_cases_data)
# Out:
# pyvirtualdisplay successfully imported
# Tests # 42 , Rewards 90.0 , Steps 90
# Tests # 900 , Rewards 92.0 , Steps 92
# Tests # 930 , Rewards 87.0 , Steps 87
# Tests # 180 , Rewards 91.0 , Steps 91
# Tests # 660 , Rewards 96.0 , Steps 96
# Tests # 240 , Rewards 90.0 , Steps 90
# Tests # 960 , Rewards 91.0 , Steps 91
# Tests # 450 , Rewards 90.0 , Steps 90
# Tests # 30 , Rewards 89.0 , Steps 89
# Tests # 90 , Rewards 95.0 , Steps 95
# Tests # 150 , Rewards 88.0 , Steps 88
# Tests # 210 , Rewards 95.0 , Steps 95
# Tests # 330 , Rewards 88.0 , Steps 88
# Tests # 420 , Rewards 92.0 , Steps 92
# Tests # 510 , Rewards 89.0 , Steps 89
# Tests # 75 , Rewards 93.0 , Steps 93

# %%
import IPython.display as display
import ipywidgets as widgets
from ipywidgets import GridspecLayout

rows=8
cols=4
grid = GridspecLayout(rows,cols)
index_of_img=0
for i in range(0,rows,2):
    for j in range(cols):
        
        path_of_img=image_paths[index_of_img]
        img=open(path_of_img,'rb').read()
        
        grid[i, j] = widgets.Image(value=img, format='gif', width=220, height=510)
        grid[i+1, j] = widgets.HTML(value=path_of_img[path_of_img.index('IMAGES/')+7 :])
        index_of_img+=1
        
        

grid
# Out:
# GridspecLayout(children=(Image(value=b'GIF89aX\x02\x90\x01\x82\x00\x00\x00\x00\x00\xcc\x99fff\xcc\x99\x99\xcc\…
